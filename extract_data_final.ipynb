# %% [markdown]
# # Data extraction script

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
from os.path import isfile, join
import numpy as np
import ast
import matplotlib.pyplot as plt
import warnings
import csv
import datetime as dt

# %%
path = "data/dysfunctional-ball-task-final"
files = []
for file in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    files.append(file)# pd.read_csv(file, quoting=csv.QUOTE_MINIMAL, engine='python')))

# %%
files
# Out:
# ['data/dysfunctional-ball-task-final\\5537b204fdf99b51eefed679.csv',
#  'data/dysfunctional-ball-task-final\\56e4b2e044b184000b894159.csv',
#  'data/dysfunctional-ball-task-final\\5731e2e45b8b06000f7e3671.csv',
#  'data/dysfunctional-ball-task-final\\5883a935c0c9a10001df6345.csv',
#  'data/dysfunctional-ball-task-final\\59cb95053306be000195be2e.csv',
#  'data/dysfunctional-ball-task-final\\59dd90f6e75b450001a68dac.csv',
#  'data/dysfunctional-ball-task-final\\5a1dda5480acd8000104a12b.csv',
#  'data/dysfunctional-ball-task-final\\5a9aa66a35237b000112937b.csv',
#  'data/dysfunctional-ball-task-final\\5aea25acd9f2be0001933493.csv',
#  'data/dysfunctional-ball-task-final\\5b5f23420085cb0001872849.csv',
#  'data/dysfunctional-ball-task-final\\5bfd8910eed5280001ead1dd.csv',
#  'data/dysfunctional-ball-task-final\\5c2b339a85602a00012ffedd.csv',
#  'data/dysfunctional-ball-task-final\\5c39ed7a688b59000102a145.csv',
#  'data/dysfunctional-ball-task-final\\5c4f7b99b33a5300013dbfdd.csv',
#  'data/dysfunctional-ball-task-final\\5c59ceb27e554c0001257ff4.csv',
#  'data/dysfunctional-ball-task-final\\5c629b836e03a00001d47bdd.csv',
#  'data/dysfunctional-ball-task-final\\5c63e773f9b6300001c9ce20.csv',
#  'data/dysfunctional-ball-task-final\\5c66cc9246bfc200019044b8.csv',
#  'data/dysfunctional-ball-task-final\\5c9d88bb2b3c77001744ec1c.csv',
#  'data/dysfunctional-ball-task-final\\5cab22cd68194f001511b2d6.csv',
#  'data/dysfunctional-ball-task-final\\5d1290103b20b0000102e8e3.csv',
#  'data/dysfunctional-ball-task-final\\5d617ba9364f9a0019f1dac3.csv',
#  'data/dysfunctional-ball-task-final\\5d6e3252dfe6d10001dbe508.csv',
#  'data/dysfunctional-ball-task-final\\5d8e154af2858200171fdb95.csv',
#  'data/dysfunctional-ball-task-final\\5d9a55cb01556d0013fa8369.csv',
#  'data/dysfunctional-ball-task-final\\5da03c3607c83700140a3d8f.csv',
#  'data/dysfunctional-ball-task-final\\5daae19f8a06b60016d1bc32.csv',
#  'data/dysfunctional-ball-task-final\\5e203085ac30fa331b586690.csv',
#  'data/dysfunctional-ball-task-final\\5e31aeefc549ee023d351eab.csv',
#  'data/dysfunctional-ball-task-final\\5eb2a99596070102a65d32c7.csv',
#  'data/dysfunctional-ball-task-final\\5f0214e58782120a8c970fd6.csv',
#  'data/dysfunctional-ball-task-final\\5f06eefaf3fc742667b4e79d.csv',
#  'data/dysfunctional-ball-task-final\\5f0a7dec44c42c19a6c9f6d9.csv',
#  'data/dysfunctional-ball-task-final\\5f2448855226b0000a8129e1.csv',
#  'data/dysfunctional-ball-task-final\\5f3287b83428cb05746e2214.csv',
#  'data/dysfunctional-ball-task-final\\5f60f6b65bd9c0022dcf9ace.csv',
#  'data/dysfunctional-ball-task-final\\5fe0b183d8918b2030aa99a0.csv',
#  'data/dysfunctional-ball-task-final\\60056657125e50465c15533e.csv',
#  'data/dysfunctional-ball-task-final\\60196480480c1403e32285a8.csv',
#  'data/dysfunctional-ball-task-final\\60292aabf20c7d2af65541a7.csv',
#  'data/dysfunctional-ball-task-final\\603a293ee62ae15da2674441.csv',
#  'data/dysfunctional-ball-task-final\\60547b4561f591f963b10ca7.csv',
#  'data/dysfunctional-ball-task-final\\605b838b80f022835fc293fb.csv',
#  'data/dysfunctional-ball-task-final\\606e3cce02e2e8a8c965ca75.csv',
#  'data/dysfunctional-ball-task-final\\609b9e5b48f112f4cc38fb76.csv',
#  'data/dysfunctional-ball-task-final\\609fba4900794b6d944da77e.csv',
#  'data/dysfunctional-ball-task-final\\60a0dfc6f9936b0d30dfea15.csv',
#  'data/dysfunctional-ball-task-final\\60a50457d02bfc23c02d4717.csv',
#  'data/dysfunctional-ball-task-final\\60aad516e34718d318bfb44d.csv',
#  'data/dysfunctional-ball-task-final\\60ad28c6d838565067ab1b6c.csv',
#  'data/dysfunctional-ball-task-final\\60c8a4ece55be5a30e0ccc5c.csv',
#  'data/dysfunctional-ball-task-final\\60cd16e63d3924958e8d3d43.csv',
#  'data/dysfunctional-ball-task-final\\60ddcd80bbeb3c7f8958f6bf.csv',
#  'data/dysfunctional-ball-task-final\\60f06a479c4f3ec0a536d40a.csv',
#  'data/dysfunctional-ball-task-final\\60f41ae35227aa02240ba0d9.csv',
#  'data/dysfunctional-ball-task-final\\60f6acaed2336346c8997195.csv',
#  'data/dysfunctional-ball-task-final\\60fd34d68de7efbcd7de57a0.csv',
#  'data/dysfunctional-ball-task-final\\6106be7d513dcab805d524b8.csv',
#  'data/dysfunctional-ball-task-final\\61099a311cb3f711346d1b05.csv',
#  'data/dysfunctional-ball-task-final\\611cd5bfd7197f8a2a3682d1.csv',
#  'data/dysfunctional-ball-task-final\\611d0afbb2a19acfd012545b.csv',
#  'data/dysfunctional-ball-task-final\\611e2d4ad083c861391122b2.csv',
#  'data/dysfunctional-ball-task-final\\6122f45e2e93a3ff9a7b7a5d.csv',
#  'data/dysfunctional-ball-task-final\\61248a51eefb6797024ecb85.csv',
#  'data/dysfunctional-ball-task-final\\6129dca465e41b5ae1b262da.csv',
#  'data/dysfunctional-ball-task-final\\6140ef8d27499e70e8740918.csv',
#  'data/dysfunctional-ball-task-final\\614de26d812e1b34acd48dfb.csv',
#  'data/dysfunctional-ball-task-final\\614e1c414dff2e589169f360.csv',
#  'data/dysfunctional-ball-task-final\\61601e9a6b8306196d2a129c.csv',
#  'data/dysfunctional-ball-task-final\\61715a02a3c88f5fb082a424.csv',
#  'data/dysfunctional-ball-task-final\\61717173748006894b2b54ff.csv',
#  'data/dysfunctional-ball-task-final\\6172d51173f6962cef6b18cf.csv',
#  'data/dysfunctional-ball-task-final\\63e51ccb431bed8154fc6aae.csv',
#  'data/dysfunctional-ball-task-final\\642cb1f7f42c4e0a6c5d4eef.csv',
#  'data/dysfunctional-ball-task-final\\64401708880c30ec28b9aef4.csv',
#  'data/dysfunctional-ball-task-final\\646219bb0b91a6f3327e39fb.csv',
#  'data/dysfunctional-ball-task-final\\646a16e2aae07a0225cdb635.csv',
#  'data/dysfunctional-ball-task-final\\647df23a62de26114fdcb29c.csv',
#  'data/dysfunctional-ball-task-final\\64d23e803ee1da9a01e52faa.csv',
#  'data/dysfunctional-ball-task-final\\650ac282d9578d72800bf303.csv',
#  'data/dysfunctional-ball-task-final\\6523351ec0163b9e739d13ab.csv',
#  'data/dysfunctional-ball-task-final\\653a6a7224e6c0bfb644ff9b.csv',
#  'data/dysfunctional-ball-task-final\\6565f2ba13586fa869dd3b28.csv',
#  'data/dysfunctional-ball-task-final\\65a3f461bfa22dde98c10436.csv',
#  'data/dysfunctional-ball-task-final\\65a4a7343830fdcc679739e0.csv',
#  'data/dysfunctional-ball-task-final\\65a93241fc1ee8c40991a861.csv',
#  'data/dysfunctional-ball-task-final\\65cb0f21257c8a98f470bb5d.csv',
#  'data/dysfunctional-ball-task-final\\65f0831414fd6e9e51e08708.csv',
#  'data/dysfunctional-ball-task-final\\65f19a1fe38352676f83d5f0.csv',
#  'data/dysfunctional-ball-task-final\\65fad673a546ab14baf2f8d3.csv',
#  'data/dysfunctional-ball-task-final\\65fae23bd06ae76bcc297e8b.csv',
#  'data/dysfunctional-ball-task-final\\65faedca7e439b344f133fdb.csv',
#  'data/dysfunctional-ball-task-final\\65fb13bebfa339f73b4cf76a.csv',
#  'data/dysfunctional-ball-task-final\\65feaaac53eb219f09ad5ea0.csv',
#  'data/dysfunctional-ball-task-final\\660eafee7515c432e850362d.csv',
#  'data/dysfunctional-ball-task-final\\6612e7f231d13a67b8e758cc.csv',
#  'data/dysfunctional-ball-task-final\\6617c54a41ce14946db85944.csv',
#  'data/dysfunctional-ball-task-final\\661d1672f01169fe41f1f001.csv',
#  'data/dysfunctional-ball-task-final\\661fcd42e06a76702b43ba20.csv',
#  'data/dysfunctional-ball-task-final\\6620f5de5edae6e60f556986.csv',
#  'data/dysfunctional-ball-task-final\\663b638be7226d4e3fcc255f.csv',
#  'data/dysfunctional-ball-task-final\\663ba5be68b9831a7ee50cfc.csv',
#  'data/dysfunctional-ball-task-final\\66446d88662725412dc27d06.csv',
#  'data/dysfunctional-ball-task-final\\664b3888f484550fe6d377bc.csv',
#  'data/dysfunctional-ball-task-final\\664b4f0017b082f48ee8a033.csv',
#  'data/dysfunctional-ball-task-final\\664b7cea18fe17cd31b5ab5e.csv',
#  'data/dysfunctional-ball-task-final\\664c9a37d570871d534dd3c2.csv',
#  'data/dysfunctional-ball-task-final\\664e413a5f3eb7f99d90e15b.csv',
#  'data/dysfunctional-ball-task-final\\6655ebfe7ae504e7ac8a35d7.csv',
#  'data/dysfunctional-ball-task-final\\66565f702a8c21be63eb93ce.csv',
#  'data/dysfunctional-ball-task-final\\6658ba167affbe300577b93d.csv',
#  'data/dysfunctional-ball-task-final\\665f10dc49cd980fdf304c19.csv',
#  'data/dysfunctional-ball-task-final\\665f239f78bd39782ef04172.csv',
#  'data/dysfunctional-ball-task-final\\666316060a19030e10987142.csv',
#  'data/dysfunctional-ball-task-final\\666408427db5e38fe0ea1736.csv',
#  'data/dysfunctional-ball-task-final\\666c4699beb014a7b85ccea1.csv',
#  'data/dysfunctional-ball-task-final\\6672fea3fe6378e257b6ef25.csv',
#  'data/dysfunctional-ball-task-final\\66742c4307bb2004831faaef.csv',
#  'data/dysfunctional-ball-task-final\\667ac09492ea0caadf488520.csv',
#  'data/dysfunctional-ball-task-final\\667ea46bc52ef1879aec2fbb.csv',
#  'data/dysfunctional-ball-task-final\\66826c452acc243fa7b92f51.csv',
#  'data/dysfunctional-ball-task-final\\668daa061b4a36bcfd2591c6.csv',
#  'data/dysfunctional-ball-task-final\\668ffb93b25dcfcfbe1836a4.csv',
#  'data/dysfunctional-ball-task-final\\669149873799bbea50733fe0.csv',
#  'data/dysfunctional-ball-task-final\\66952367721687887540318f.csv',
#  'data/dysfunctional-ball-task-final\\6697c4e76e01a2e71f34cd33.csv',
#  'data/dysfunctional-ball-task-final\\6697c8b6d9d7baa7edd8c4d3.csv',
#  'data/dysfunctional-ball-task-final\\669bba2714caa691679bff24.csv',
#  'data/dysfunctional-ball-task-final\\669bd8ce24b83b4652aebd40.csv',
#  'data/dysfunctional-ball-task-final\\669c1e1fdb95a995eb1d3077.csv',
#  'data/dysfunctional-ball-task-final\\669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-final\\66a16e0b41e98cb469f12b0b.csv',
#  'data/dysfunctional-ball-task-final\\66a6211743bf2623c0a8eb81.csv',
#  'data/dysfunctional-ball-task-final\\66a79fce251c3b3fedb04d16.csv',
#  'data/dysfunctional-ball-task-final\\66aea8fcd9cd711541bf63e5.csv',
#  'data/dysfunctional-ball-task-final\\66b61da8697a1059a78e7008.csv',
#  'data/dysfunctional-ball-task-final\\66bb2110c5672f09961feed2.csv',
#  'data/dysfunctional-ball-task-final\\66bee53cfe67b3e6342cb2ba.csv',
#  'data/dysfunctional-ball-task-final\\66c5f76d9a214b469f6476c8.csv',
#  'data/dysfunctional-ball-task-final\\66c7397fb877280a42dcd495.csv',
#  'data/dysfunctional-ball-task-final\\66ce541cd8da920539a1c3cc.csv',
#  'data/dysfunctional-ball-task-final\\66cf43db332889da5054c9e8.csv',
#  'data/dysfunctional-ball-task-final\\66db15814e7818d8b9593ad5.csv',
#  'data/dysfunctional-ball-task-final\\66ebc8c5e5b772065830754d.csv',
#  'data/dysfunctional-ball-task-final\\66f4c82536b5c8271f53564c.csv',
#  'data/dysfunctional-ball-task-final\\66f56ad3380290fe0bf7c4f8.csv',
#  'data/dysfunctional-ball-task-final\\6702f60844f21087e0840e3d.csv',
#  'data/dysfunctional-ball-task-final\\671b802adc0489faede54d81.csv',
#  'data/dysfunctional-ball-task-final\\671d0e15c134a5355de39a6d.csv',
#  'data/dysfunctional-ball-task-final\\67215aa0a8e88c6751efc410.csv',
#  'data/dysfunctional-ball-task-final\\6729f8c001f004ff58eb68b8.csv',
#  'data/dysfunctional-ball-task-final\\672c8a3b9fb83ab9c5f02fd2.csv',
#  'data/dysfunctional-ball-task-final\\672de198be1065a8f288300d.csv',
#  'data/dysfunctional-ball-task-final\\672f51ea346fba23ddd5a793.csv',
#  'data/dysfunctional-ball-task-final\\672f7b856c1ce6995a666bc6.csv',
#  'data/dysfunctional-ball-task-final\\673594215b1a0b92d5835525.csv',
#  'data/dysfunctional-ball-task-final\\6742fd0efbb5712e14e693e5.csv',
#  'data/dysfunctional-ball-task-final\\6743c8da977b0d274dad1fc2.csv',
#  'data/dysfunctional-ball-task-final\\6744700ac7a3406e40f009c5.csv',
#  'data/dysfunctional-ball-task-final\\6744814c173b9afac78cf039.csv',
#  'data/dysfunctional-ball-task-final\\67458e548861194752950b3e.csv',
#  'data/dysfunctional-ball-task-final\\6745d8ba436b1416f92aa9b8.csv',
#  'data/dysfunctional-ball-task-final\\674da5296d8cc775b40c8311.csv',
#  'data/dysfunctional-ball-task-final\\674eae0026291e33be89b46f.csv',
#  'data/dysfunctional-ball-task-final\\675ee689e18bf69c5cb1b944.csv',
#  'data/dysfunctional-ball-task-final\\676054ef296caad582258e02.csv',
#  'data/dysfunctional-ball-task-final\\676055e6c41940f91e59028c.csv',
#  'data/dysfunctional-ball-task-final\\6760580745ecb73102f83f3d.csv',
#  'data/dysfunctional-ball-task-final\\676578b520552faa04a8ef83.csv',
#  'data/dysfunctional-ball-task-final\\6769cc78e79f747dda9c7b8f.csv',
#  'data/dysfunctional-ball-task-final\\676e882e8a97b91ee272efe4.csv',
#  'data/dysfunctional-ball-task-final\\6771ad00548b3a182d5f80e0.csv',
#  'data/dysfunctional-ball-task-final\\677fb45dee7e90f416b55aea.csv',
#  'data/dysfunctional-ball-task-final\\6780db9dafd89add339abb6b.csv',
#  'data/dysfunctional-ball-task-final\\6785052a054e7c96c09f69cd.csv',
#  'data/dysfunctional-ball-task-final\\6786c32f329b1d694103f225.csv',
#  'data/dysfunctional-ball-task-final\\67895942fcb6400a74aebfca.csv',
#  'data/dysfunctional-ball-task-final\\678bad003d15e6aba1ee5a5d.csv',
#  'data/dysfunctional-ball-task-final\\678f8c443d3e97127a5e529b.csv',
#  'data/dysfunctional-ball-task-final\\6792a60bf1238ae52e645ecb.csv',
#  'data/dysfunctional-ball-task-final\\67acf1d438e2c92a40f88a9e.csv',
#  'data/dysfunctional-ball-task-final\\67adeb124ea5587ac8afa3ac.csv',
#  'data/dysfunctional-ball-task-final\\67b89f64c09d83ec36fdd403.csv',
#  'data/dysfunctional-ball-task-final\\67b9e921b4b5ee4019522dbb.csv',
#  'data/dysfunctional-ball-task-final\\67bfed4a6c0630c5f857b23e.csv',
#  'data/dysfunctional-ball-task-final\\67c6e102bbdf6801c9a2642a.csv',
#  'data/dysfunctional-ball-task-final\\67cac9c704712b2393e52905.csv',
#  'data/dysfunctional-ball-task-final\\67ceea767be1306940ed6800.csv',
#  'data/dysfunctional-ball-task-final\\67d0052a3f36525d24f021be.csv',
#  'data/dysfunctional-ball-task-final\\67d057fe81435b77cf5a4681.csv',
#  'data/dysfunctional-ball-task-final\\67d163e7b7bcc1e9718e01da.csv',
#  'data/dysfunctional-ball-task-final\\67d548b5aa5737666a77a6d2.csv',
#  'data/dysfunctional-ball-task-final\\67d7fa657f5ac0292a291a38.csv',
#  'data/dysfunctional-ball-task-final\\67d846e847a41d29a7f6fcb3.csv',
#  'data/dysfunctional-ball-task-final\\67d95269b47464c18da766ca.csv',
#  'data/dysfunctional-ball-task-final\\67db387c909560bc7b65ea88.csv',
#  'data/dysfunctional-ball-task-final\\67dc19c31078d1581e39e75a.csv',
#  'data/dysfunctional-ball-task-final\\67e161beb708693951a94cbd.csv',
#  'data/dysfunctional-ball-task-final\\67e1a47dae2e2e04aa7d8417.csv',
#  'data/dysfunctional-ball-task-final\\67e575f103799e89aacd209c.csv',
#  'data/dysfunctional-ball-task-final\\67e94945e5f6a3090ed5a9d0.csv',
#  'data/dysfunctional-ball-task-final\\67eab317b6f969b3df440160.csv',
#  'data/dysfunctional-ball-task-final\\67eaee55a9b4d89e82b8df37.csv',
#  'data/dysfunctional-ball-task-final\\67f133dcba790167d0027963.csv',
#  'data/dysfunctional-ball-task-final\\67f14975a8c12321ab2d0e61.csv',
#  'data/dysfunctional-ball-task-final\\67f38b0b1f5fe0543c6e66ed.csv',
#  'data/dysfunctional-ball-task-final\\67fa89d6790924c25e5ffb8e.csv',
#  'data/dysfunctional-ball-task-final\\67fb8218748357094cba6869.csv',
#  'data/dysfunctional-ball-task-final\\6820e30a98ebaa472670fd3d.csv',
#  'data/dysfunctional-ball-task-final\\683dda03c88521ebe8cba79e.csv',
#  'data/dysfunctional-ball-task-final\\undefined.csv']

# %% [markdown]
# ## Extract data

# %% [markdown]
# ### Per trial

# %%
columns_normal = [
    "prolific_id", 
    "SESSION_ID", 
    "STUDY_ID", 
    "trial_number", 
    "tutorial_trial_number", 
    "control_level",
    "trial_start_time",
    "phase1_start_time",
    "phase2_start_time",
    "phase3_start_time",
    "goals_layout",
    "goal_1_value",
    "goal_1_distance",
    "goal_2_value",
    "goal_2_distance",
    "goal_selected",
    "participant_initial_score",
    "participant_final_score",
    "outcome",
    "outcome_total",
    "participant_final_score_prop",
    "goal_choice_rt",
    "allocated_time",
    "allocated_time_remaining",
    "goal_direction",
    "key_presses"

]

columns_counts = [
    "num_key_presses",
    "num_perfect",
    "num_errors",
    "num_randdir",
    "num_randdir_good_moves",
    "num_whilered",
    "num_whileblue",
    "num_blue",
    "num_good_moves",
]

columns_post_trial = [
    "AttribQ",
    "ControlQ",
    "StressQ",
    "MotivationQ",
]

columns_pre_post_task = [
    "PreSkillQ",
    "PrePerfQ",
    "PreMotivationQ",
    "PostSkillQ", 
    "PostPerfQ",
    "PostMotivationQ"
]

columns_questionnaires = [
    "pss",
    "drsp",
    "stress",
    "phq"
]
columns_questionnaires_type2 = ["phq_diff"]


# columns_demographics = [
#     "age",
#     "gender_identity",
#     "assigned_sex",
#     "menstrual_cycle",
#     "education",
#     "education_parents"]

columns_reproductive_health = [
    "bleeding",
    "pregnancy",
    "hormonal_contraceptives",
    "affect_hormones",
]


columns_session = ["record_date", "duration_assessment"]
# columns_mental_health = [
#     "mental_health_condition","mental_health_treatment","psychiatric_medication",
#     "depression_history","depression_episodes","depression_recent"
# ]

columns = []
columns.extend(columns_normal)
columns.extend(columns_counts)
columns.extend(columns_post_trial)
columns.extend(columns_questionnaires)
columns.extend(columns_questionnaires_type2)
columns.extend(columns_pre_post_task)
# columns.extend(columns_demographics)
# columns.extend(columns_mental_health)
columns.extend(columns_reproductive_health)
columns.extend(columns_session)

# %%
# helpe fu:

def grab_first(data, key, array=False, column="response"):
    """
    Extract the first occurrence of `key` from a JSON-like string column.
    - data: DataFrame or Series
    - key: key to extract
    - array: True if the value is like ["Yes"]
    - column: column name if `data` is a DataFrame
    """
    ser = data if isinstance(data, pd.Series) else data[column]
    if array:
        pat = rf'"{key}"\s*:\s*\[\s*"([^"]*)"'
    else:
        pat = rf'"{key}"\s*:\s*"([^"]*)"'
    s = ser.astype(str).str.extract(pat, expand=False).dropna()
    return s.iloc[0] if not s.empty else np.nan

# %%
len_all = []
for file_name in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    file = pd.read_csv(file_name, quoting=csv.QUOTE_MINIMAL, engine='python')
    len_all.append(len(file))

# %%
plt.figure(figsize=(6,4))
plt.hist(len_all, bins=30, color="#4C78A8", edgecolor="white")
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Histogram")
plt.show()

# %%
# baseline data:
per_trial_data = pd.DataFrame(columns=columns)
path = "data/dysfunctional-ball-task-final"
for file_name in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    file = pd.read_csv(file_name, quoting=csv.QUOTE_MINIMAL, engine='python')
    if (len(file) > 100):
        
        reproductive_health_data = [
            grab_first(file, "bleeding", array=True),
            grab_first(file, "pregnancy", array=True),
            grab_first(file, "hormonal_contraceptives", array=True),
            grab_first(file, "affect_hormones", array=True),
        ]
        questionnaires = []
        no_questionnaire = False
        for i in range(len(file)):
            try:
                if file.loc[i]["eventType"] in columns_questionnaires:
                    questionnaires.append(file.loc[i]["responses"])
            except KeyError:
                no_questionnaire = True
                break
        if no_questionnaire:
            break
        while len(questionnaires) < len(columns_questionnaires):
            questionnaires.append(np.nan)
               
        questionnaires_type2 = []
        no_questionnaire_type2 = False
        for i in range(len(file)):
            try:
                if file.loc[i]["eventType"] in columns_questionnaires_type2:
                    questionnaires_type2.append(file.loc[i]["response"])
            except KeyError:
                no_questionnaire_type2 = True
                break
        if no_questionnaire_type2:
            break
        while len(questionnaires_type2) < len(columns_questionnaires_type2):
            questionnaires_type2.append(np.nan)

        questionnaires_pre_post_task = []
        no_questionnaire_pre_post = False
        for i in range(len(file)):
            try:
                if file.loc[i]["eventType"] in columns_pre_post_task:
                    questionnaires_pre_post_task.append(file.loc[i]["response"])
            except KeyError:
                no_questionnaire_pre_post = True
                break
        if no_questionnaire_pre_post:
            print('no pre_post for i ' + str(i))
            break
        while len(questionnaires_pre_post_task) < len(questionnaires_pre_post_task):
            questionnaires_pre_post_task.append(np.nan)
        session_data = [
            file["recorded_at"].iloc[0],
            file["response_timestamp"].max()  - file["response_timestamp"].min() ]

        for i in range(len(file)):
            trial_data = file.loc[i]
            if trial_data["trial_type"] == "ctl-task-cpt":
                row_data = []
                for label in columns_normal:
                    row_data.append(trial_data[label])
                counts = ast.literal_eval(trial_data["counts"])
                for key in columns_counts:
                    row_data.append(counts[key])
                for j in range(len(columns_post_trial)):
                    if trial_data["trial_number"] != 0 and len(file) > i + 1 + j:
                        row_data.append(file.loc[i + 1 + j]["response"])
                    else:
                        row_data.append(np.nan)
                row_data.extend(questionnaires)
                row_data.extend(questionnaires_type2)
                row_data.extend(questionnaires_pre_post_task)
                # row_data.extend(demographics) 
                # row_data.extend(mental_health_data) 
                row_data.extend(reproductive_health_data) 
                row_data.extend(session_data) 
                per_trial_data.loc[len(per_trial_data)] = row_data

# %%
per_trial_data.to_csv("per_trial_data_final.csv")
