# %% [markdown]
# # Data extraction script

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
from os.path import isfile, join
import numpy as np
import ast
import matplotlib.pyplot as plt
import warnings
import csv
import datetime as dt

# %%
path = "data/dysfunctional-ball-task-weekly"
files = []
for file in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    files.append(file)# pd.read_csv(file, quoting=csv.QUOTE_MINIMAL, engine='python')))

# %%
files
# Out:
# ['data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_06_6140ef8d27499e70e8740918.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_22_678bad003d15e6aba1ee5a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_39_653a6a7224e6c0bfb644ff9b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_47_646219bb0b91a6f3327e39fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_54_66a4f108a03ede09bb40255c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_38_59_5d1290103b20b0000102e8e3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_39_00_665f239f78bd39782ef04172.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_39_16_669c1e1fdb95a995eb1d3077.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_39_21_665f10dc49cd980fdf304c19.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_39_30_615d8873c11a1982c8838b54.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_40_24_65f19a1fe38352676f83d5f0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_40_32_66952367721687887540318f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_40_59_60a50457d02bfc23c02d4717.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_41_22_6658ba167affbe300577b93d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_41_59_6760580745ecb73102f83f3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_42_27_663b638be7226d4e3fcc255f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_43_02_6620f5de5edae6e60f556986.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_48_55_61099a311cb3f711346d1b05.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_49_59_5f3287b83428cb05746e2214.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 08_54_48_5d9a55cb01556d0013fa8369.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 09_02_16_674eae0026291e33be89b46f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 09_23_37_5a1dda5480acd8000104a12b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 09_28_01_5d8e154af2858200171fdb95.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 09_33_04_5b5f23420085cb0001872849.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 10_19_04_66a16e0b41e98cb469f12b0b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 10_21_18_60f7c71d1cffec381351b0b3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 11_05_11_5d617ba9364f9a0019f1dac3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 11_31_05_672f7b856c1ce6995a666bc6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 12_22_22_676054ef296caad582258e02.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 12_58_30_6129dca465e41b5ae1b262da.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-09 15_52_20_67215aa0a8e88c6751efc410.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-10 12_14_57_61248a51eefb6797024ecb85.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-10 12_23_10_65a93241fc1ee8c40991a861.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-14 14_43_23_66db15814e7818d8b9593ad5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_16_38_5c2b339a85602a00012ffedd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_01_61601e9a6b8306196d2a129c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_15_60ad28c6d838565067ab1b6c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_20_614e1c414dff2e589169f360.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_25_669a686f263cbcb8e321ed85.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_33_60292aabf20c7d2af65541a7.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_36_5dd25456cc192027096069bb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_17_52_59cb95053306be000195be2e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_18_09_605b838b80f022835fc293fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_18_10_60c8a4ece55be5a30e0ccc5c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_18_11_67e074f58a5ea7d9897f3223.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_19_22_6780db9dafd89add339abb6b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_19_54_6736f4a8fe83ffce0936bdc4.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_20_09_671a44d9d93641d1d9e96883.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_20_41_6744814c173b9afac78cf039.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_21_13_673594215b1a0b92d5835525.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_21_17_6743c8da977b0d274dad1fc2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_21_20_67f14975a8c12321ab2d0e61.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_22_27_650ac282d9578d72800bf303.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_22_30_5c39ed7a688b59000102a145.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_22_40_67c7672373207a4fb29efe7f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_24_43_667abff30a4bfe675c592b14.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_25_24_664b3888f484550fe6d377bc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_26_10_6612e7f231d13a67b8e758cc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_27_03_60f41ae35227aa02240ba0d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_29_07_5f0214e58782120a8c970fd6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_29_09_65f19a1fe38352676f83d5f0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_29_38_60a50457d02bfc23c02d4717.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_29_58_61099a311cb3f711346d1b05.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_30_45_6786c32f329b1d694103f225.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_30_56_5f3287b83428cb05746e2214.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_31_01_615d8873c11a1982c8838b54.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_31_13_674eae0026291e33be89b46f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_31_33_67b89f64c09d83ec36fdd403.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_31_43_5cab22cd68194f001511b2d6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_31_56_66c5f76d9a214b469f6476c8.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_32_37_5d8e154af2858200171fdb95.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_33_37_653a6a7224e6c0bfb644ff9b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_34_26_6140ef8d27499e70e8740918.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_34_41_5d9a55cb01556d0013fa8369.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_34_48_5a9aa66a35237b000112937b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_37_25_66a16e0b41e98cb469f12b0b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_38_56_667b366d0d0943e90dbee7d1.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_40_40_646219bb0b91a6f3327e39fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_41_02_672c8a3b9fb83ab9c5f02fd2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_53_26_6792a60bf1238ae52e645ecb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_54_42_666408427db5e38fe0ea1736.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_56_11_65cb0f21257c8a98f470bb5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 08_58_54_669149873799bbea50733fe0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_07_03_6702f60844f21087e0840e3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_11_15_67eaee55a9b4d89e82b8df37.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_14_33_663b638be7226d4e3fcc255f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_15_04_5c63e773f9b6300001c9ce20.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_28_01_665f10dc49cd980fdf304c19.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_28_23_676578b520552faa04a8ef83.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_41_52_6658ba167affbe300577b93d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_41_52_678bad003d15e6aba1ee5a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 09_52_23_5daae19f8a06b60016d1bc32.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_01_55_6172d51173f6962cef6b18cf.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_07_00_60056657125e50465c15533e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_12_37_65a93241fc1ee8c40991a861.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_14_53_5a1dda5480acd8000104a12b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_20_46_60f7c71d1cffec381351b0b3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_25_35_59dd90f6e75b450001a68dac.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_38_47_606e3cce02e2e8a8c965ca75.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_39_46_5e203085ac30fa331b586690.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_46_11_642cb1f7f42c4e0a6c5d4eef.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_50_06_66952367721687887540318f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 10_51_41_6122f45e2e93a3ff9a7b7a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 11_13_23_5b5f23420085cb0001872849.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 11_52_53_67eab317b6f969b3df440160.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 12_05_10_65f0831414fd6e9e51e08708.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 12_11_54_65f0831414fd6e9e51e08708.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 12_13_12_5d617ba9364f9a0019f1dac3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 13_09_54_67b9e921b4b5ee4019522dbb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 13_16_45_60aad516e34718d318bfb44d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 13_23_08_665f239f78bd39782ef04172.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 13_28_13_676054ef296caad582258e02.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 13_56_45_6565f2ba13586fa869dd3b28.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 15_21_22_66f4c82536b5c8271f53564c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 16_01_21_677fb45dee7e90f416b55aea.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 16_04_39_669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 16_11_39_6785052a054e7c96c09f69cd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 16_13_34_672f7b856c1ce6995a666bc6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 16_59_15_6129dca465e41b5ae1b262da.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 18_26_30_6698f8ca0354d4ef9692bf7a.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 18_48_26_66a6211743bf2623c0a8eb81.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 18_51_56_669c1e1fdb95a995eb1d3077.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 19_22_25_6760580745ecb73102f83f3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 20_02_08_5c4f7b99b33a5300013dbfdd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-16 22_00_18_67215aa0a8e88c6751efc410.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-17 07_39_24_56e4b2e044b184000b894159.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-17 10_00_40_66db15814e7818d8b9593ad5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-17 23_53_17_61248a51eefb6797024ecb85.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-18 13_32_30_674766f8e0307c4de164f7d6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-18 21_45_19_66aea8fcd9cd711541bf63e5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-21 07_34_11_66ebc8c5e5b772065830754d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-21 09_29_06_5f0a7dec44c42c19a6c9f6d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-22 08_11_21_676e882e8a97b91ee272efe4.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_29_18_614e1c414dff2e589169f360.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_29_21_60292aabf20c7d2af65541a7.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_29_54_65cb0f21257c8a98f470bb5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_30_17_669a686f263cbcb8e321ed85.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_30_21_60c8a4ece55be5a30e0ccc5c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_30_50_677fb45dee7e90f416b55aea.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_30_53_605b838b80f022835fc293fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_31_16_664b3888f484550fe6d377bc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_31_38_67f14975a8c12321ab2d0e61.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_32_08_6140ef8d27499e70e8740918.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_32_22_5d8e154af2858200171fdb95.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_32_33_61099a311cb3f711346d1b05.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_33_21_67c7672373207a4fb29efe7f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_33_57_67b9e921b4b5ee4019522dbb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_34_03_65f19a1fe38352676f83d5f0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_34_17_66aea8fcd9cd711541bf63e5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_35_56_67b89f64c09d83ec36fdd403.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_37_04_663b638be7226d4e3fcc255f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_37_53_6743c8da977b0d274dad1fc2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_38_16_5c2b339a85602a00012ffedd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_38_23_669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_38_40_5c2b339a85602a00012ffedd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_39_20_6786c32f329b1d694103f225.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_43_57_60f41ae35227aa02240ba0d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_46_05_5d9a55cb01556d0013fa8369.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_46_36_66952367721687887540318f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_52_11_665f10dc49cd980fdf304c19.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_53_51_60056657125e50465c15533e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 06_56_04_6744814c173b9afac78cf039.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_04_04_667abff30a4bfe675c592b14.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_05_28_676054ef296caad582258e02.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_07_42_5a9aa66a35237b000112937b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_08_06_60f41ae35227aa02240ba0d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_18_12_5d1290103b20b0000102e8e3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_26_09_60ad28c6d838565067ab1b6c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_26_50_653a6a7224e6c0bfb644ff9b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_27_42_669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_31_31_669c1e1fdb95a995eb1d3077.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_34_05_676578b520552faa04a8ef83.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_34_30_669149873799bbea50733fe0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_34_47_66c5f76d9a214b469f6476c8.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_35_53_5f3287b83428cb05746e2214.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_36_15_60a50457d02bfc23c02d4717.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_37_26_667b366d0d0943e90dbee7d1.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_46_13_6122f45e2e93a3ff9a7b7a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_52_58_59cb95053306be000195be2e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 07_53_11_66a16e0b41e98cb469f12b0b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_04_27_67e074f58a5ea7d9897f3223.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_04_51_66a6211743bf2623c0a8eb81.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_06_28_61601e9a6b8306196d2a129c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_07_50_665f239f78bd39782ef04172.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_12_24_671a44d9d93641d1d9e96883.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_19_07_5cab22cd68194f001511b2d6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_34_33_5c4f7b99b33a5300013dbfdd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_38_08_642cb1f7f42c4e0a6c5d4eef.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_39_45_5daae19f8a06b60016d1bc32.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_44_01_669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_45_03_5a1dda5480acd8000104a12b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_50_18_65a93241fc1ee8c40991a861.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 08_51_29_65f0831414fd6e9e51e08708.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 09_02_17_676e882e8a97b91ee272efe4.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 09_03_05_672c8a3b9fb83ab9c5f02fd2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 09_11_47_6172d51173f6962cef6b18cf.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 09_33_37_60aad516e34718d318bfb44d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 09_43_34_646219bb0b91a6f3327e39fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 10_22_30_666408427db5e38fe0ea1736.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 10_31_25_606e3cce02e2e8a8c965ca75.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 10_32_17_606e3cce02e2e8a8c965ca75.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 10_37_34_67eaee55a9b4d89e82b8df37.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 10_48_22_66db15814e7818d8b9593ad5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 11_00_30_6792a60bf1238ae52e645ecb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 11_09_06_5d617ba9364f9a0019f1dac3.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 11_33_09_6658ba167affbe300577b93d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 11_39_36_650ac282d9578d72800bf303.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 12_16_26_5dd25456cc192027096069bb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 12_16_38_67eab317b6f969b3df440160.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 12_52_00_672f7b856c1ce6995a666bc6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 13_16_29_6780db9dafd89add339abb6b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 13_23_34_678bad003d15e6aba1ee5a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 13_25_06_6785052a054e7c96c09f69cd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 13_43_34_66f4c82536b5c8271f53564c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 14_01_51_67d163e7b7bcc1e9718e01da.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 15_05_04_6612e7f231d13a67b8e758cc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 15_30_24_6565f2ba13586fa869dd3b28.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 16_55_05_5b5f23420085cb0001872849.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 17_43_33_6702f60844f21087e0840e3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 17_49_53_66ebc8c5e5b772065830754d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 18_31_30_6129dca465e41b5ae1b262da.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 19_04_40_5e203085ac30fa331b586690.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 19_11_47_5c39ed7a688b59000102a145.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 19_35_46_59dd90f6e75b450001a68dac.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 20_14_38_674eae0026291e33be89b46f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-23 20_32_18_67215aa0a8e88c6751efc410.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-24 00_41_40_673594215b1a0b92d5835525.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-24 09_41_28_5f0214e58782120a8c970fd6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-24 09_42_26_6760580745ecb73102f83f3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-24 20_49_38_56e4b2e044b184000b894159.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-25 18_30_33_61248a51eefb6797024ecb85.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-29 09_02_45_5f0a7dec44c42c19a6c9f6d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 04_40_46_67599ff233234e646e9fe3ca.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_36_28_605b838b80f022835fc293fb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_36_49_67f14975a8c12321ab2d0e61.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_36_56_6785052a054e7c96c09f69cd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_37_02_5c4f7b99b33a5300013dbfdd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_37_19_65cb0f21257c8a98f470bb5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_37_21_5daae19f8a06b60016d1bc32.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_37_33_672c8a3b9fb83ab9c5f02fd2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_37_53_614e1c414dff2e589169f360.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_38_03_6780db9dafd89add339abb6b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_38_45_60c8a4ece55be5a30e0ccc5c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_38_48_67e074f58a5ea7d9897f3223.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_39_48_66aea8fcd9cd711541bf63e5.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_40_24_67b9e921b4b5ee4019522dbb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_40_55_614e1c414dff2e589169f360.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_42_39_6702f60844f21087e0840e3d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_43_18_650ac282d9578d72800bf303.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_43_34_66f4c82536b5c8271f53564c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_44_49_666408427db5e38fe0ea1736.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_47_23_673594215b1a0b92d5835525.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_49_28_6743c8da977b0d274dad1fc2.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_51_54_5cab22cd68194f001511b2d6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_52_24_5c63e773f9b6300001c9ce20.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 08_57_13_669149873799bbea50733fe0.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_01_25_59cb95053306be000195be2e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_01_47_67d163e7b7bcc1e9718e01da.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_01_51_664b3888f484550fe6d377bc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_02_45_5a9aa66a35237b000112937b.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_03_51_67b89f64c09d83ec36fdd403.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_05_36_61601e9a6b8306196d2a129c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_10_23_67b89f64c09d83ec36fdd403.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_10_35_6612e7f231d13a67b8e758cc.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 09_40_43_673594215b1a0b92d5835525.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 10_00_39_669f76a7112b8713f104644c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 10_08_35_642cb1f7f42c4e0a6c5d4eef.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 10_33_18_60292aabf20c7d2af65541a7.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 11_12_55_60f41ae35227aa02240ba0d9.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 11_49_59_67eab317b6f969b3df440160.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 11_50_25_6792a60bf1238ae52e645ecb.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 12_15_50_60ad28c6d838565067ab1b6c.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 13_14_49_676578b520552faa04a8ef83.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 13_55_07_6172d51173f6962cef6b18cf.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 15_00_47_6744814c173b9afac78cf039.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 16_06_47_5c39ed7a688b59000102a145.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 16_08_27_60aad516e34718d318bfb44d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 16_32_48_undefined.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 17_05_57_606e3cce02e2e8a8c965ca75.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 18_55_07_60056657125e50465c15533e.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 21_12_31_56e4b2e044b184000b894159.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 22_49_28_5f0214e58782120a8c970fd6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-30 23_23_59_5f0214e58782120a8c970fd6.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 05_25_32_65f0831414fd6e9e51e08708.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 05_37_47_66ebc8c5e5b772065830754d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 06_33_42_67eaee55a9b4d89e82b8df37.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 06_41_47_6122f45e2e93a3ff9a7b7a5d.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 06_54_04_677fb45dee7e90f416b55aea.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 10_54_03_66a6211743bf2623c0a8eb81.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-07-31 21_35_35_59dd90f6e75b450001a68dac.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-01 08_15_11_5e203085ac30fa331b586690.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-01 15_41_54_67c7672373207a4fb29efe7f.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-01 18_07_03_66c5f76d9a214b469f6476c8.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-03 14_10_52_6565f2ba13586fa869dd3b28.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-04 09_20_54_5c2b339a85602a00012ffedd.csv',
#  'data/dysfunctional-ball-task-weekly\\2025-08-05 04_05_42_5f0a7dec44c42c19a6c9f6d9.csv']

# %% [markdown]
# ## Extract data

# %% [markdown]
# ### Per trial

# %%
columns_normal = [
    "prolific_id", 
    "SESSION_ID", 
    "STUDY_ID", 
    "trial_number", 
    "tutorial_trial_number", 
    "control_level",
    "trial_start_time",
    "phase1_start_time",
    "phase2_start_time",
    "phase3_start_time",
    "goals_layout",
    "goal_1_value",
    "goal_1_distance",
    "goal_2_value",
    "goal_2_distance",
    "goal_selected",
    "participant_initial_score",
    "participant_final_score",
    "outcome",
    "outcome_total",
    "participant_final_score_prop",
    "goal_choice_rt",
    "allocated_time",
    "allocated_time_remaining",
    "goal_direction",
    "key_presses"
]

columns_counts = [
    "num_key_presses",
    "num_perfect",
    "num_errors",
    "num_randdir",
    "num_randdir_good_moves",
    "num_whilered",
    "num_whileblue",
    "num_blue",
    "num_good_moves",
]

columns_post_trial = [
    "AttribQ",
    "ControlQ",
    "StressQ",
    "MotivationQ",
]

columns_pre_post_task = [
    "PreSkillQ",
    "PrePerfQ",
    "PreMotivationQ",
    "PostSkillQ", 
    "PostPerfQ",
    "PostMotivationQ"
]

# columns_questionnaires = [
#     "phq",
#     "shaps",
#     "ius",
#     "gad",
#     "pss",
#     "drsp",
#     "stress",
#     "psst_symptoms",
#     "psst_interference"
# ]

columns_questionnaires = [
    "drsp",
    "stress",
]

# columns_demographics = [
#     "age",
#     "gender_identity",
#     "assigned_sex",
#     "menstrual_cycle",
#     "education",
#     "education_parents"]

columns_reproductive_health = [
    "bleeding",
    "date",
    "cycle_certainty",
    "pregnancy",
    "attention_check",
    "hormonal_contraceptives",
    "affect_hormones",
]


columns_session = ["record_date", "duration_assessment"]
# columns_mental_health = [
#     "mental_health_condition","mental_health_treatment","psychiatric_medication",
#     "depression_history","depression_episodes","depression_recent"
# ]

columns = []
columns.extend(columns_normal)
columns.extend(columns_counts)
columns.extend(columns_post_trial)
# columns.extend(columns_questionnaires)
columns.extend(columns_questionnaires)
columns.extend(columns_pre_post_task)
# columns.extend(columns_demographics)
# columns.extend(columns_mental_health)
columns.extend(columns_reproductive_health)
columns.extend(columns_session)

# %%
# helpe fu:

def grab_first(data, key, array=False, column="response"):
    """
    Extract the first occurrence of `key` from a JSON-like string column.
    - data: DataFrame or Series
    - key: key to extract
    - array: True if the value is like ["Yes"]
    - column: column name if `data` is a DataFrame
    """
    ser = data if isinstance(data, pd.Series) else data[column]
    if array:
        pat = rf'"{key}"\s*:\s*\[\s*"([^"]*)"'
    else:
        pat = rf'"{key}"\s*:\s*"([^"]*)"'
    s = ser.astype(str).str.extract(pat, expand=False).dropna()
    return s.iloc[0] if not s.empty else np.nan

# %%
# per_trial_data.loc[len(per_trial_data)] = row_data
len(row_data)
print(file_name)
# Out:
# data/dysfunctional-ball-task-baseline\2025-07-09 09_13_48_5ff81ab8d6f3fa546efbad4e.csv

# %%
len_all = []
for file_name in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    file = pd.read_csv(file_name, quoting=csv.QUOTE_MINIMAL, engine='python')
    len_all.append(len(file))

# %%
plt.figure(figsize=(6,4))
plt.hist(len_all, bins=30, color="#4C78A8", edgecolor="white")
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Histogram")
plt.show()

# %%
file
i = 20
print(file_name)

trial_data = file.loc[i]
trial_data["prolific_id"]
            # if trial_data["trial_type"] == "ctl-task-cpt":
            #     row_data = []
            #     for label in columns_normal:
            #         row_data.append(trial_data[label])
# Out:
# data/dysfunctional-ball-task-weekly\2025-07-30 16_32_48_undefined.csv
# np.float64(nan)

# %%
# baseline data:
per_trial_data = pd.DataFrame(columns=columns)
path = "data/dysfunctional-ball-task-weekly"
for file_name in [join(path, f) for f in os.listdir(path) if (isfile(join(path, f)) and f[0] != '.')]:
    file = pd.read_csv(file_name, quoting=csv.QUOTE_MINIMAL, engine='python')
    if (len(file) > 100):
        
        reproductive_health_data = [
            grab_first(file, "bleeding", array=True),
            grab_first(file, "date"),
            grab_first(file, "cycle_certainty"),
            grab_first(file, "pregnancy", array=True),
            grab_first(file, "attention_check", array=True),
            grab_first(file, "hormonal_contraceptives", array=True),
            grab_first(file, "affect_hormones", array=True),
        ]
        questionnaires = []
        no_questionnaire = False
        for i in range(len(file)):
            try:
                if file.loc[i]["eventType"] in columns_questionnaires:
                    questionnaires.append(file.loc[i]["responses"])
            except KeyError:
                no_questionnaire = True
                break
        if no_questionnaire:
            break
        while len(questionnaires) < len(columns_questionnaires):
            questionnaires.append(np.nan)
               
        # questionnaires_type2 = []
        # no_questionnaire_type2 = False
        # for i in range(len(file)):
        #     try:
        #         if file.loc[i]["eventType"] in columns_questionnaires_type2:
        #             questionnaires_type2.append(file.loc[i]["response"])
        #     except KeyError:
        #         no_questionnaire_type2 = True
        #         break
        # if no_questionnaire_type2:
        #     break
        # while len(questionnaires_type2) < len(columns_questionnaires_type2):
        #     questionnaires_type2.append(np.nan)

        questionnaires_pre_post_task = []
        no_questionnaire_pre_post = False
        for i in range(len(file)):
            try:
                if file.loc[i]["eventType"] in columns_pre_post_task:
                    questionnaires_pre_post_task.append(file.loc[i]["response"])
            except KeyError:
                no_questionnaire_pre_post = True
                break
        if no_questionnaire_pre_post:
            print('no pre_post for i ' + str(i))
            break
        while len(questionnaires_pre_post_task) < len(questionnaires_pre_post_task):
            questionnaires_pre_post_task.append(np.nan)
        session_data = [
            file["recorded_at"].iloc[0],
            file["response_timestamp"].max()  - file["response_timestamp"].min() ]

        for i in range(len(file)):
            trial_data = file.loc[i]
            if trial_data["trial_type"] == "ctl-task-cpt":
                row_data = []
                for label in columns_normal:
                    row_data.append(trial_data[label])
                counts = ast.literal_eval(trial_data["counts"])
                for key in columns_counts:
                    row_data.append(counts[key])
                for j in range(len(columns_post_trial)):
                    if trial_data["trial_number"] != 0 and len(file) > i + 1 + j:
                        row_data.append(file.loc[i + 1 + j]["response"])
                    else:
                        row_data.append(np.nan)
                # row_data.extend(questionnaires)
                row_data.extend(questionnaires)
                row_data.extend(questionnaires_pre_post_task)
                # row_data.extend(demographics) 
                # row_data.extend(mental_health_data) 
                row_data.extend(reproductive_health_data) 
                row_data.extend(session_data) 
                per_trial_data.loc[len(per_trial_data)] = row_data

# %%
per_trial_data.to_csv("per_trial_data_weekly.csv")
